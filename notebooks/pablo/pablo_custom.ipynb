# %% [markdown]
# # Image classification with 'image_dataset_from_directory' method

# %% [markdown]
# # Creating train/val/test datasets using split-folders package

# %% [markdown]
# The split-folders package allow us to create 3 folders of train/val/test images
#
# The input folder should have the following format (Gregoire's function output):
#
# input/
#
#     class1/
#         img1.jpg
#         img2.jpg
#         ...
#     class2/
#         imgWhatever.jpg
#         ...
#     ...
#
#
# And we get this
#
# output/
#
#     train/
#         class1/
#             img1.jpg
#             ...
#         class2/
#             imga.jpg
#             ...
#
#     val/
#
#         class1/
#
#             img2.jpg
#             ...
#         class2/
#             imgb.jpg
#             ...
#     test/
#         class1/
#             img3.jpg
#             ...
#         class2/
#             imgc.jpg
#             ...

# %%
TRAIN_RATIO = 0.8
VAL_RATIO = 0.1
TEST_RATIO = 0.1

assert TRAIN_RATIO + VAL_RATIO + TEST_RATIO == 1
assert TRAIN_RATIO != 0
assert VAL_RATIO != 0
assert TEST_RATIO != 0

# %%
import splitfolders
# !rm -rf "/home/jupyter/wikiart/train_val_test_True_1440"
splitfolders.ratio("/home/jupyter/wikiart/wikiart-movement-genre_True-class_8-merge_mov-1-n_1440_max", 
                   output="/home/jupyter/wikiart/train_val_test_True_1440",
                   seed=1337, ratio=(TRAIN_RATIO, VAL_RATIO, TEST_RATIO), 
                   group_prefix=None);
# Out:
# Copying files: 11520 files [00:20, 573.46 files/s]

# %% [markdown]
# # Deep learning workflow

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import datetime
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers, models, applications

# Note : we are using TensorFlow Core v2.5.0, in TensorFlow Core v2.6.0 all the data augmentaation layers are part of tf.keras.layers
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation, RandomZoom, Rescaling
from tensorflow.keras import Input, Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adamax

# %% [markdown]
# ## Global variables

# %%
USERNAME = 'pablo'
MODEL = 'Custom'

MAIN_PATH = '/home/jupyter/' 
DATASETS_FOLDER = 'wikiart/train_val_test_True_1440/'

TRAIN_DIR = MAIN_PATH + DATASETS_FOLDER + 'train'
VAL_DIR = MAIN_PATH + DATASETS_FOLDER + 'val'
TEST_DIR = MAIN_PATH + DATASETS_FOLDER + 'test'

# %%
BATCH_SIZE = 128
EPOCHS = 1000
IMG_HEIGHT = 224
IMG_WIDTH = 224
NUM_CLASSES = 8

# %% [markdown]
# ## Datasets setup

# %% [markdown]
# ### Train dataset

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory=TRAIN_DIR,
    labels='inferred',
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    shuffle=True)

assert len(train_ds.class_names) == NUM_CLASSES
# Out:
# Found 9216 files belonging to 8 classes.

# %% [markdown]
# ### Validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory=VAL_DIR,
    labels='inferred',
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    label_mode='categorical',
    batch_size=BATCH_SIZE)

assert len(val_ds.class_names) == NUM_CLASSES
# Out:
# Found 1152 files belonging to 8 classes.

# %% [markdown]
# ### Test dataset

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory=TEST_DIR,
    labels='inferred',
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    label_mode='categorical',
    batch_size=BATCH_SIZE)

assert len(test_ds.class_names) == NUM_CLASSES
# Out:
# Found 1155 files belonging to 8 classes.

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['abstract',
#  'color_field_painting',
#  'cubism',
#  'expressionism',
#  'impressionism',
#  'realism',
#  'renaissance',
#  'romanticism']

# %%
total_images_count = (int(len(list(train_ds)))+int(len(list(val_ds)))+int(len(list(test_ds))))*BATCH_SIZE
# total_images_count = 33011 + 4123 + 4134
total_images_count
# Out:
# 11520

# %% [markdown]
# ## Dataset optimization for performance

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(int(total_images_count/10)).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Model : custom

# %% [markdown]
# ### Data augmentation layers

# %%
data_augmentation_layers = models.Sequential([
    RandomFlip("horizontal", input_shape=(224, 224,3)),
    RandomRotation(0.3),
    RandomZoom(0.3)])

# %% [markdown]
# ### Model setup

# %%
model = Sequential([
    layers.InputLayer(input_shape=(224, 224, 3)),
    Rescaling(1./255),
    data_augmentation_layers,
    layers.Conv2D(8, 3, padding='same', activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.3),
    layers.Conv2D(128, 3, padding='same', activation='relu'),
    layers.Flatten(),
    layers.Dropout(0.4),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(8, activation='softmax')
    
])

# Batch normalization

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# sequential (Sequential)      (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1605696
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 520
# =================================================================
# Total params: 1,704,600
# Trainable params: 1,704,600
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Callbacks

# %% [markdown]
# #### EarlyStopping

# %%
es = EarlyStopping(monitor='val_loss', patience=20, mode='min', restore_best_weights=True)

# %% [markdown]
# #### ReduceLROnPlateau

# %%
rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.4, patience=3, min_lr=1e-8)

# %% [markdown]
# #### ModelCheckpoint

# %%
checkpoint_dir = f"{MAIN_PATH}logs/{USERNAME}/{MODEL}/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
mcp = ModelCheckpoint(
    filepath=checkpoint_dir,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_freq=10,
    save_best_only=True)

# %%
# %load_ext tensorboard
# !rm -rf ./logs/ResNet50
recorded_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S") 
log_dir = f"{MAIN_PATH}logs/{USERNAME}/{MODEL}/" + \
    recorded_time + \
    f"-images_{total_images_count}" + \
    f"-batch_{BATCH_SIZE}"
tsboard = TensorBoard(log_dir=log_dir) # voir https public

# %% [markdown]
# ### Model compilation

# %%
model.compile(optimizer=Adamax(learning_rate=0.01), 
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

# %% [markdown]
# ### Model fitting

# %%
history = model.fit(
    train_ds, 
    epochs=EPOCHS, 
    validation_data=val_ds, 
    callbacks=[es, rlrp, tsboard])

model.save(f"{MAIN_PATH}models/{USERNAME}/{MODEL}/" + \
    recorded_time + \
    f"-images_{total_images_count}" + \
    f"-batch_{BATCH_SIZE}")
# Out:
# Epoch 1/1000
# 72/72 [==============================] - 39s 126ms/step - loss: 2.1305 - accuracy: 0.1424 - val_loss: 2.0227 - val_accuracy: 0.1675
# Epoch 2/1000
# 72/72 [==============================] - 6s 87ms/step - loss: 1.9835 - accuracy: 0.1841 - val_loss: 2.0828 - val_accuracy: 0.1684
# Epoch 3/1000
# 72/72 [==============================] - 6s 87ms/step - loss: 1.9579 - accuracy: 0.2030 - val_loss: 2.0236 - val_accuracy: 0.1918
# Epoch 4/1000
# 72/72 [==============================] - 6s 87ms/step - loss: 1.9327 - accuracy: 0.2158 - val_loss: 1.9529 - val_accuracy: 0.2300
# Epoch 5/1000
# 72/72 [==============================] - 6s 87ms/step - loss: 1.9099 - accuracy: 0.2250 - val_loss: 1.8861 - val_accuracy: 0.2491
# Epoch 6/1000
# 72/72 [==============================] - 6s 88ms/step - loss: 1.8804 - accuracy: 0.2428 - val_loss: 1.8614 - val_accuracy: 0.2630
# Epoch 7/1000
# 72/72 [==============================] - 6s 88ms/step - loss: 1.8438 - accuracy: 0.2663 - val_loss: 1.7349 - val_accuracy: 0.3229
# Epoch 8/1000
# 72/72 [==============================] - 6s 88ms/step - loss: 1.7989 - accuracy: 0.2886 - val_loss: 1.6801 - val_accuracy: 0.3299
# Epoch 9/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.7678 - accuracy: 0.2998 - val_loss: 1.6355 - val_accuracy: 0.3568
# Epoch 10/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.7213 - accuracy: 0.3176 - val_loss: 1.6425 - val_accuracy: 0.3490
# Epoch 11/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.7153 - accuracy: 0.3147 - val_loss: 1.6254 - val_accuracy: 0.3516
# Epoch 12/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.6893 - accuracy: 0.3304 - val_loss: 1.6302 - val_accuracy: 0.3663
# Epoch 13/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.6781 - accuracy: 0.3276 - val_loss: 1.6370 - val_accuracy: 0.3802
# Epoch 14/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.6606 - accuracy: 0.3427 - val_loss: 1.5952 - val_accuracy: 0.3802
# Epoch 15/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.6538 - accuracy: 0.3441 - val_loss: 1.5559 - val_accuracy: 0.3906
# Epoch 16/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.6611 - accuracy: 0.3441 - val_loss: 1.5913 - val_accuracy: 0.3715
# Epoch 17/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.6360 - accuracy: 0.3490 - val_loss: 1.5593 - val_accuracy: 0.3967
# Epoch 18/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.6246 - accuracy: 0.3512 - val_loss: 1.5206 - val_accuracy: 0.3932
# Epoch 19/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.6008 - accuracy: 0.3628 - val_loss: 1.5304 - val_accuracy: 0.4097
# Epoch 20/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.6095 - accuracy: 0.3726 - val_loss: 1.5514 - val_accuracy: 0.3889
# Epoch 21/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.6181 - accuracy: 0.3559 - val_loss: 1.5122 - val_accuracy: 0.4062
# Epoch 22/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.5981 - accuracy: 0.3655 - val_loss: 1.5296 - val_accuracy: 0.4080
# Epoch 23/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.5781 - accuracy: 0.3798 - val_loss: 1.5107 - val_accuracy: 0.4010
# Epoch 24/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.5842 - accuracy: 0.3755 - val_loss: 1.4894 - val_accuracy: 0.4132
# Epoch 25/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.5703 - accuracy: 0.3860 - val_loss: 1.5110 - val_accuracy: 0.3950
# Epoch 26/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.5822 - accuracy: 0.3755 - val_loss: 1.4897 - val_accuracy: 0.4089
# Epoch 27/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.5749 - accuracy: 0.3777 - val_loss: 1.4562 - val_accuracy: 0.4366
# Epoch 28/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.5571 - accuracy: 0.3934 - val_loss: 1.4943 - val_accuracy: 0.4010
# Epoch 29/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.5513 - accuracy: 0.3952 - val_loss: 1.4816 - val_accuracy: 0.4201
# Epoch 30/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.5420 - accuracy: 0.3992 - val_loss: 1.4753 - val_accuracy: 0.4141
# Epoch 31/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4921 - accuracy: 0.4170 - val_loss: 1.4584 - val_accuracy: 0.4280
# Epoch 32/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4952 - accuracy: 0.4179 - val_loss: 1.4421 - val_accuracy: 0.4453
# Epoch 33/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4771 - accuracy: 0.4230 - val_loss: 1.4419 - val_accuracy: 0.4297
# Epoch 34/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4859 - accuracy: 0.4294 - val_loss: 1.4345 - val_accuracy: 0.4245
# Epoch 35/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4725 - accuracy: 0.4243 - val_loss: 1.4143 - val_accuracy: 0.4540
# Epoch 36/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4689 - accuracy: 0.4298 - val_loss: 1.4187 - val_accuracy: 0.4392
# Epoch 37/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4574 - accuracy: 0.4443 - val_loss: 1.4432 - val_accuracy: 0.4219
# Epoch 38/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4465 - accuracy: 0.4425 - val_loss: 1.3992 - val_accuracy: 0.4688
# Epoch 39/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4557 - accuracy: 0.4436 - val_loss: 1.4374 - val_accuracy: 0.4375
# Epoch 40/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4511 - accuracy: 0.4372 - val_loss: 1.4054 - val_accuracy: 0.4523
# Epoch 41/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4389 - accuracy: 0.4489 - val_loss: 1.4469 - val_accuracy: 0.4332
# Epoch 42/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4138 - accuracy: 0.4567 - val_loss: 1.3902 - val_accuracy: 0.4731
# Epoch 43/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4128 - accuracy: 0.4597 - val_loss: 1.3783 - val_accuracy: 0.4679
# Epoch 44/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4206 - accuracy: 0.4505 - val_loss: 1.3874 - val_accuracy: 0.4592
# Epoch 45/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4082 - accuracy: 0.4553 - val_loss: 1.4341 - val_accuracy: 0.4601
# Epoch 46/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4102 - accuracy: 0.4612 - val_loss: 1.3706 - val_accuracy: 0.4714
# Epoch 47/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4073 - accuracy: 0.4630 - val_loss: 1.3993 - val_accuracy: 0.4653
# Epoch 48/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3853 - accuracy: 0.4688 - val_loss: 1.3659 - val_accuracy: 0.4679
# Epoch 49/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3946 - accuracy: 0.4600 - val_loss: 1.3976 - val_accuracy: 0.4549
# Epoch 50/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3893 - accuracy: 0.4680 - val_loss: 1.4014 - val_accuracy: 0.4557
# Epoch 51/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.4011 - accuracy: 0.4685 - val_loss: 1.4128 - val_accuracy: 0.4540
# Epoch 52/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3813 - accuracy: 0.4681 - val_loss: 1.3778 - val_accuracy: 0.4740
# Epoch 53/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3704 - accuracy: 0.4696 - val_loss: 1.4022 - val_accuracy: 0.4653
# Epoch 54/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3732 - accuracy: 0.4701 - val_loss: 1.3692 - val_accuracy: 0.4774
# Epoch 55/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3587 - accuracy: 0.4763 - val_loss: 1.3652 - val_accuracy: 0.4844
# Epoch 56/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3661 - accuracy: 0.4738 - val_loss: 1.3711 - val_accuracy: 0.4748
# Epoch 57/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3634 - accuracy: 0.4737 - val_loss: 1.3755 - val_accuracy: 0.4731
# Epoch 58/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3530 - accuracy: 0.4821 - val_loss: 1.3650 - val_accuracy: 0.4740
# Epoch 59/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.3626 - accuracy: 0.4746 - val_loss: 1.3673 - val_accuracy: 0.4705
# Epoch 60/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3607 - accuracy: 0.4754 - val_loss: 1.3670 - val_accuracy: 0.4722
# Epoch 61/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3487 - accuracy: 0.4811 - val_loss: 1.3723 - val_accuracy: 0.4766
# Epoch 62/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3564 - accuracy: 0.4752 - val_loss: 1.3664 - val_accuracy: 0.4757
# Epoch 63/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3534 - accuracy: 0.4840 - val_loss: 1.3666 - val_accuracy: 0.4757
# Epoch 64/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3542 - accuracy: 0.4822 - val_loss: 1.3743 - val_accuracy: 0.4757
# Epoch 65/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3533 - accuracy: 0.4832 - val_loss: 1.3692 - val_accuracy: 0.4731
# Epoch 66/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3535 - accuracy: 0.4772 - val_loss: 1.3649 - val_accuracy: 0.4748
# Epoch 67/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3602 - accuracy: 0.4784 - val_loss: 1.3656 - val_accuracy: 0.4757
# Epoch 68/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3504 - accuracy: 0.4800 - val_loss: 1.3701 - val_accuracy: 0.4731
# Epoch 69/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3651 - accuracy: 0.4830 - val_loss: 1.3681 - val_accuracy: 0.4748
# Epoch 70/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3548 - accuracy: 0.4799 - val_loss: 1.3662 - val_accuracy: 0.4731
# Epoch 71/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3529 - accuracy: 0.4816 - val_loss: 1.3646 - val_accuracy: 0.4731
# Epoch 72/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3605 - accuracy: 0.4780 - val_loss: 1.3646 - val_accuracy: 0.4748
# Epoch 73/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3570 - accuracy: 0.4747 - val_loss: 1.3644 - val_accuracy: 0.4757
# Epoch 74/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3520 - accuracy: 0.4786 - val_loss: 1.3658 - val_accuracy: 0.4748
# Epoch 75/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3535 - accuracy: 0.4804 - val_loss: 1.3639 - val_accuracy: 0.4740
# Epoch 76/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3492 - accuracy: 0.4847 - val_loss: 1.3662 - val_accuracy: 0.4748
# Epoch 77/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3482 - accuracy: 0.4860 - val_loss: 1.3656 - val_accuracy: 0.4757
# Epoch 78/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3453 - accuracy: 0.4780 - val_loss: 1.3672 - val_accuracy: 0.4783
# Epoch 79/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3546 - accuracy: 0.4771 - val_loss: 1.3662 - val_accuracy: 0.4766
# Epoch 80/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3569 - accuracy: 0.4804 - val_loss: 1.3649 - val_accuracy: 0.4740
# Epoch 81/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3505 - accuracy: 0.4812 - val_loss: 1.3655 - val_accuracy: 0.4757
# Epoch 82/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3487 - accuracy: 0.4824 - val_loss: 1.3651 - val_accuracy: 0.4748
# Epoch 83/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3640 - accuracy: 0.4794 - val_loss: 1.3650 - val_accuracy: 0.4748
# Epoch 84/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3512 - accuracy: 0.4857 - val_loss: 1.3650 - val_accuracy: 0.4748
# Epoch 85/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3523 - accuracy: 0.4765 - val_loss: 1.3651 - val_accuracy: 0.4748
# Epoch 86/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3452 - accuracy: 0.4848 - val_loss: 1.3649 - val_accuracy: 0.4748
# Epoch 87/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3535 - accuracy: 0.4806 - val_loss: 1.3649 - val_accuracy: 0.4748
# Epoch 88/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3439 - accuracy: 0.4821 - val_loss: 1.3649 - val_accuracy: 0.4748
# Epoch 89/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3585 - accuracy: 0.4800 - val_loss: 1.3650 - val_accuracy: 0.4748
# Epoch 90/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3549 - accuracy: 0.4816 - val_loss: 1.3650 - val_accuracy: 0.4748
# Epoch 91/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3455 - accuracy: 0.4885 - val_loss: 1.3650 - val_accuracy: 0.4748
# Epoch 92/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3579 - accuracy: 0.4813 - val_loss: 1.3650 - val_accuracy: 0.4748
# Epoch 93/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3436 - accuracy: 0.4875 - val_loss: 1.3650 - val_accuracy: 0.4748
# Epoch 94/1000
# 72/72 [==============================] - 6s 89ms/step - loss: 1.3460 - accuracy: 0.4814 - val_loss: 1.3650 - val_accuracy: 0.4748
# Epoch 95/1000
# 72/72 [==============================] - 6s 90ms/step - loss: 1.3551 - accuracy: 0.4836 - val_loss: 1.3650 - val_accuracy: 0.4748
# INFO:tensorflow:Assets written to: /home/jupyter/models/pablo/Custom/20210830-131417-images_11520-batch_128/assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = history.epoch

fig = plt.figure(figsize=(16, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
fig.savefig(f"/home/jupyter/figures/{USERNAME}/{MODEL}/{recorded_time}-images_{total_images_count}-batch_{BATCH_SIZE}", dpi=300)

# %%
model.evaluate(test_ds, callbacks=tsboard)
# Out:
# 9/9 [==============================] - 3s 42ms/step - loss: 1.3544 - accuracy: 0.4714
# [1.3544485569000244, 0.4713541567325592]

# %% [markdown]
# ## Test prediction

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
layer_outputs = [layer.output for layer in model.layers[2:]]
layer_outputs
# Out:
# [<KerasTensor: shape=(None, 224, 224, 8) dtype=float32 (created by layer 'conv2d')>,
#  <KerasTensor: shape=(None, 112, 112, 8) dtype=float32 (created by layer 'max_pooling2d')>,
#  <KerasTensor: shape=(None, 112, 112, 16) dtype=float32 (created by layer 'conv2d_1')>,
#  <KerasTensor: shape=(None, 56, 56, 16) dtype=float32 (created by layer 'max_pooling2d_1')>,
#  <KerasTensor: shape=(None, 56, 56, 32) dtype=float32 (created by layer 'conv2d_2')>,
#  <KerasTensor: shape=(None, 28, 28, 32) dtype=float32 (created by layer 'max_pooling2d_2')>,
#  <KerasTensor: shape=(None, 28, 28, 64) dtype=float32 (created by layer 'conv2d_3')>,
#  <KerasTensor: shape=(None, 14, 14, 64) dtype=float32 (created by layer 'max_pooling2d_3')>,
#  <KerasTensor: shape=(None, 14, 14, 64) dtype=float32 (created by layer 'dropout')>,
#  <KerasTensor: shape=(None, 14, 14, 128) dtype=float32 (created by layer 'conv2d_4')>,
#  <KerasTensor: shape=(None, 25088) dtype=float32 (created by layer 'flatten')>,
#  <KerasTensor: shape=(None, 25088) dtype=float32 (created by layer 'dropout_1')>,
#  <KerasTensor: shape=(None, 64) dtype=float32 (created by layer 'dense')>,
#  <KerasTensor: shape=(None, 64) dtype=float32 (created by layer 'dropout_2')>,
#  <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'dense_1')>]

# %%
visualize_model = tf.keras.models.Model(model.input, layer_outputs)
visualize_model

# %%
# !pwd
# Out:
# /home/jupyter/notebooks/movement

# %%
img = load_img('/home/jupyter/image_pred/color-field-painting_claude-viallat_unknown-title-3.jpg', target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FBF382FFBD0>

# %%
x = img_to_array(img)
x = x.reshape((1, 224, 224, 3))
x.shape
x = x/255
# Out:
# (1, 224, 224, 3)

# %%
pred = model.predict(x)

# %%
print(f"1. {class_names[np.argsort(np.max(pred, axis=0))[-1]]} ':' {round(pred[0][np.argsort(np.max(pred, axis=0))[-1]]*100, 2)}%")
print(f"2. {class_names[np.argsort(np.max(pred, axis=0))[-2]]} ':' {round(pred[0][np.argsort(np.max(pred, axis=0))[-2]]*100, 2)}%")
print(f"3. {class_names[np.argsort(np.max(pred, axis=0))[-3]]} ':' {round(pred[0][np.argsort(np.max(pred, axis=0))[-3]]*100, 2)}%")
# Out:
# 1. color_field_painting ':' 79.67%
# 2. romanticism ':' 9.34%
# 3. abstract ':' 8.87%
